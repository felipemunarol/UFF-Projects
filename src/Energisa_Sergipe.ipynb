# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemunarol/UFF-Projects/blob/main/src/Energisa_Sergipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Filtra os conjunto somente da Energisa Sergipe para o teste da inferencia do modelo

# %%
import csv
import pandas as pd
import os
import json

pd.set_option('display.max_columns', None)

# Conecta o serviço com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Raiz
! ls '/content/drive/MyDrive/Mestrado/Ordens_servico/'
# Out:
# 'Apresentacoes Andamento'  'Doc Dissertação.gdoc'  'Tese Latex'
# 'Definição Problema.gdoc'   Doc.gdoc		    Tese.pdf
#  Dissertaçao.docx	    Ordens_servico

# %% [markdown]
# # Preprocess

# %%
year = 2022

# %%
interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))
# Out:
# <ipython-input-5-39954c25d839>:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))

# %%
# interrupcoes[interrupcoes.NomAgenteRegulado.str.contains("ENERGISA") & interrupcoes.NomAgenteRegulado.str.contains("SERGIPE")]

interrupcoes = interrupcoes[interrupcoes.NumCPFCNPJ == 13017462000163]

# %%
interrupcoes
# Out:
#          Unnamed: 0.1  Unnamed: 0        _id DatGeracaoConjuntoDados  \
# 8073249         33249       33249  8053250.0              2023-05-26
# 8073250         33250       33250  8053251.0              2023-05-26
# 8073251         33251       33251  8053252.0              2023-05-26
# 8073252         33252       33252  8053253.0              2023-05-26
# 8073253         33253       33253  8053254.0              2023-05-26
# ...               ...         ...        ...                     ...
# 8142812        102812      102812  8122813.0              2023-05-26
# 8142813        102813      102813  8122814.0              2023-05-26
# 8142814        102814      102814  8122815.0              2023-05-26
# 8142815        102815      102815  8122816.0              2023-05-26
# 8142816        102816      102816  8122817.0              2023-05-26
#
#         DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 8073249                 SÃO CRISTOVÃO                       F4
# 8073250                         URUBU                       S2
# 8073251                 SÃO CRISTOVÃO                       F4
# 8073252                 SÃO CRISTOVÃO                       F4
# 8073253                         URUBU                       Z4
# ...                               ...                      ...
# 8142812                         URUBU                       Z5
# 8142813                       ATALAIA                       W3
# 8142814                       CABRITA                       J5
# 8142815                     MOSQUEIRO                       M4
# 8142816                     ITABAIANA                       F5
#
#         DscSubestacaoDistribuicao NumOrdemInterrupcao DscTipoInterrupcao  \
# 8073249                       SCT         2021-132264     Não Programada
# 8073250                       SRY              2022-3     Não Programada
# 8073251                       SCT         2021-132264     Não Programada
# 8073252                       SCT         2021-132264     Não Programada
# 8073253                       URB              2022-5     Não Programada
# ...                           ...                 ...                ...
# 8142812                       URB         2022-144231     Não Programada
# 8142813                       ATL         2022-144232     Não Programada
# 8142814                       CBT         2022-144233     Não Programada
# 8142815                       MSQ         2022-144235     Não Programada
# 8142816                       CJB              2023-1     Não Programada
#
#          IdeMotivoInterrupcao DatInicioInterrupcao    DatFimInterrupcao  \
# 8073249                   0.0  2022-01-01 00:24:00  2022-01-01 00:34:00
# 8073250                   0.0  2022-01-01 00:56:00  2022-01-01 07:46:07
# 8073251                   0.0  2022-01-01 00:58:00  2022-01-01 08:17:00
# 8073252                   0.0  2022-01-01 00:58:00  2022-01-01 06:28:00
# 8073253                   1.0  2022-01-01 01:41:00  2022-01-01 04:01:48
# ...                       ...                  ...                  ...
# 8142812                   1.0  2022-12-31 23:18:00  2023-01-01 11:16:29
# 8142813                   1.0  2022-12-31 23:26:00  2023-01-01 01:03:08
# 8142814                   0.0  2022-12-31 23:39:43  2023-01-01 02:20:00
# 8142815                   0.0  2022-12-31 23:46:01  2023-01-01 02:11:54
# 8142816                   0.0  2022-12-31 23:57:03  2023-01-01 01:58:00
#
#                                  DscFatoGeradorInterrupcao  NumNivelTensao  \
# 8073249  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...           127.0
# 8073250  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...           127.0
# 8073251  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...           127.0
# 8073252  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...           127.0
# 8073253        INTERNA - NAO PROGRAMADA - NAO CLASSIFICADA           127.0
# ...                                                    ...             ...
# 8142812        INTERNA - NAO PROGRAMADA - NAO CLASSIFICADA           127.0
# 8142813        INTERNA - NAO PROGRAMADA - NAO CLASSIFICADA           127.0
# 8142814  INTERNA - NAO PROGRAMADA - MEIO AMBIENTE - ARV...         13800.0
# 8142815  INTERNA - NAO PROGRAMADA - PROPRIAS DO SISTEMA...           127.0
# 8142816  INTERNA - NAO PROGRAMADA - MEIO AMBIENTE - ANI...         13800.0
#
#          NumUnidadeConsumidora  NumConsumidorConjunto  NumAno  \
# 8073249                   39.0                11427.0  2022.0
# 8073250                    1.0                65892.0  2022.0
# 8073251                   39.0                11427.0  2022.0
# 8073252                   42.0                11427.0  2022.0
# 8073253                    1.0                65892.0  2022.0
# ...                        ...                    ...     ...
# 8142812                    1.0                68212.0  2022.0
# 8142813                    1.0                68005.0  2022.0
# 8142814                  255.0                36633.0  2022.0
# 8142815                    1.0                13620.0  2022.0
# 8142816                   19.0                44488.0  2022.0
#
#                                        NomAgenteRegulado  \
# 8073249  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8073250  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8073251  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8073252  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8073253  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# ...                                                  ...
# 8142812  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8142813  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8142814  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8142815  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
# 8142816  ENERGISA SERGIPE - DISTRIBUIDORA DE ENERGIA S.A
#
#                     SigAgente    NumCPFCNPJ
# 8073249  ESE                   1.301746e+13
# 8073250  ESE                   1.301746e+13
# 8073251  ESE                   1.301746e+13
# 8073252  ESE                   1.301746e+13
# 8073253  ESE                   1.301746e+13
# ...                       ...           ...
# 8142812  ESE                   1.301746e+13
# 8142813  ESE                   1.301746e+13
# 8142814  ESE                   1.301746e+13
# 8142815  ESE                   1.301746e+13
# 8142816  ESE                   1.301746e+13
#
# [69568 rows x 20 columns]

# %%
interrupcoes_array = interrupcoes.DscConjuntoUnidadeConsumidora.values

# %%
interrupcoes_dict = {}
interrupcoes_dict["conjuntos"] = list(interrupcoes_array)
interrupcoes_dict
# Out:
# {'conjuntos': ['SÃO CRISTOVÃO',
#   'URUBU',
#   'SÃO CRISTOVÃO',
#   'SÃO CRISTOVÃO',
#   'URUBU',
#   'MOSQUEIRO',
#   'URUBU',
#   'SÃO CRISTOVÃO',
#   'ARACAJU',
#   'FREI PAULO',
#   'MOSQUEIRO',
#   'SÃO CRISTOVÃO',
#   'LAGARTO',
#   'PORTO',
#   'GRACCHO CARDOSO',
#   'XINGÓ',
#   'TAIÇOCA',
#   'MARUIM',
#   'ATALAIA',
#   'CAJAÍBA',
#   'MOITA BONITA',
#   'PORTO DA FOLHA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ITAPORANGA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ITAPORANGA',
#   'RIACHUELO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'POÇO VERDE',
#   'PORTO DA FOLHA',
#   'XINGÓ',
#   'ITAPORANGA',
#   'LAGARTO',
#   'CONTORNO',
#   'XINGÓ',
#   'CAJAÍBA',
#   'NOSSA SENHORA DAS DORES',
#   'CARMÓPOLIS',
#   'ATALAIA',
#   'MOSQUEIRO',
#   'URUBU',
#   'MOITA BONITA',
#   'MOSQUEIRO',
#   'ARACAJU',
#   'ITAPORANGA',
#   'MONTE ALEGRE',
#   'NOSSA SENHORA DA GLÓRIA',
#   'CONTORNO',
#   'PORTO',
#   'NOSSA SENHORA DAS DORES',
#   'ITABAIANA',
#   'ATALAIA',
#   'POÇO VERDE',
#   'URUBU',
#   'CABRITA',
#   'CONTORNO',
#   'POÇO VERDE',
#   'PORTO DA FOLHA',
#   'MOITA BONITA',
#   'SÃO CRISTOVÃO',
#   'XINGÓ',
#   'PORTO DA FOLHA',
#   'CARMÓPOLIS',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ITAPORANGA',
#   'MOSQUEIRO',
#   'XINGÓ',
#   'SERIGY',
#   'PROPRIÁ',
#   'FREI PAULO',
#   'ITAPORANGA',
#   'MOSQUEIRO',
#   'NOSSA SENHORA DAS DORES',
#   'TAIÇOCA',
#   'MOITA BONITA',
#   'CAJAÍBA',
#   'FREI PAULO',
#   'MARUIM',
#   'MOSQUEIRO',
#   'SALGADO',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'ATALAIA',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'ARACAJU',
#   'PROPRIÁ',
#   'MONTE ALEGRE',
#   'PROPRIÁ',
#   'SIMÃO DIAS',
#   'MONTE ALEGRE',
#   'FREI PAULO',
#   'SIMÃO DIAS',
#   'MARUIM',
#   'ATALAIA',
#   'PROPRIÁ',
#   'FREI PAULO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PROPRIÁ',
#   'ATALAIA',
#   'URUBU',
#   'MOSQUEIRO',
#   'RIACHUELO',
#   'SIMÃO DIAS',
#   'LAGARTO',
#   'XINGÓ',
#   'CARMÓPOLIS',
#   'MOITA BONITA',
#   'ARACAJU',
#   'ARACAJU',
#   'ARACAJU',
#   'ITAPORANGA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ATALAIA',
#   'ITAPORANGA',
#   'MONTE ALEGRE',
#   'FREI PAULO',
#   'ITABAIANA',
#   'MOITA BONITA',
#   'ARACAJU',
#   'PORTO',
#   'SALGADO',
#   'ITAPORANGA',
#   'NOSSA SENHORA DAS DORES',
#   'NOSSA SENHORA DAS DORES',
#   'LAGARTO',
#   'GRACCHO CARDOSO',
#   'FREI PAULO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'MOSQUEIRO',
#   'GRACCHO CARDOSO',
#   'ITAPORANGA',
#   'PROPRIÁ',
#   'ATALAIA',
#   'ATALAIA',
#   'SERIGY',
#   'NOSSA SENHORA DA GLÓRIA',
#   'SALGADO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'GRACCHO CARDOSO',
#   'PROPRIÁ',
#   'NOSSA SENHORA DA GLÓRIA',
#   'CONTORNO',
#   'PROPRIÁ',
#   'MARUIM',
#   'MARUIM',
#   'MOITA BONITA',
#   'MARUIM',
#   'ATALAIA',
#   'NOSSA SENHORA DAS DORES',
#   'ITABAIANA',
#   'MOSQUEIRO',
#   'ATALAIA',
#   'FREI PAULO',
#   'PROPRIÁ',
#   'CONTORNO',
#   'MONTE ALEGRE',
#   'MONTE ALEGRE',
#   'SÃO CRISTOVÃO',
#   'PORTO DA FOLHA',
#   'ARACAJU',
#   'MOSQUEIRO',
#   'PORTO',
#   'PROPRIÁ',
#   'FREI PAULO',
#   'PORTO',
#   'MOSQUEIRO',
#   'POÇO VERDE',
#   'CAJAÍBA',
#   'URUBU',
#   'TAIÇOCA',
#   'SÃO CRISTOVÃO',
#   'GRACCHO CARDOSO',
#   'SALGADO',
#   'NOSSA SENHORA DAS DORES',
#   'ATALAIA',
#   'NOSSA SENHORA DAS DORES',
#   'ATALAIA',
#   'PORTO DA FOLHA',
#   'GRACCHO CARDOSO',
#   'PORTO DA FOLHA',
#   'MONTE ALEGRE',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'FREI PAULO',
#   'LAGARTO',
#   'TAIÇOCA',
#   'ATALAIA',
#   'MOSQUEIRO',
#   'MOSQUEIRO',
#   'ITAPORANGA',
#   'NOSSA SENHORA DAS DORES',
#   'ATALAIA',
#   'CONTORNO',
#   'SÃO CRISTOVÃO',
#   'SÃO CRISTOVÃO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'MOSQUEIRO',
#   'ATALAIA',
#   'ATALAIA',
#   'ARACAJU',
#   'SÃO CRISTOVÃO',
#   'PORTO',
#   'ATALAIA',
#   'NOSSA SENHORA DAS DORES',
#   'PORTO',
#   'RIACHUELO',
#   'ARACAJU',
#   'ARACAJU',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'LAGARTO',
#   'PORTO',
#   'FREI PAULO',
#   'PORTO DA FOLHA',
#   'ITABAIANA',
#   'MOITA BONITA',
#   'SÃO CRISTOVÃO',
#   'FREI PAULO',
#   'GRAGERU',
#   'PROPRIÁ',
#   'CARMÓPOLIS',
#   'SIMÃO DIAS',
#   'FREI PAULO',
#   'ITABAIANA',
#   'ITAPORANGA',
#   'LAGARTO',
#   'LAGARTO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'FREI PAULO',
#   'ATALAIA',
#   'LAGARTO',
#   'MONTE ALEGRE',
#   'LAGARTO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ITABAIANA',
#   'TAIÇOCA',
#   'TAIÇOCA',
#   'LAGARTO',
#   'NOSSA SENHORA DAS DORES',
#   'GRACCHO CARDOSO',
#   'CAJAÍBA',
#   'CARMÓPOLIS',
#   'MARUIM',
#   'PORTO',
#   'PROPRIÁ',
#   'TAIÇOCA',
#   'CABRITA',
#   'MONTE ALEGRE',
#   'SALGADO',
#   'NOSSA SENHORA DAS DORES',
#   'GRACCHO CARDOSO',
#   'ITAPORANGA',
#   'URUBU',
#   'LAGARTO',
#   'NOSSA SENHORA DAS DORES',
#   'ITABAIANA',
#   'ITAPORANGA',
#   'ATALAIA',
#   'SALGADO',
#   'ATALAIA',
#   'FREI PAULO',
#   'PORTO DA FOLHA',
#   'URUBU',
#   'PORTO DA FOLHA',
#   'CARRAPICHO',
#   'CONTORNO',
#   'MARUIM',
#   'CABRITA',
#   'URUBU',
#   'SALGADO',
#   'URUBU',
#   'PROPRIÁ',
#   'TAIÇOCA',
#   'PORTO',
#   'POÇO VERDE',
#   'CARRAPICHO',
#   'CARRAPICHO',
#   'SIMÃO DIAS',
#   'PROPRIÁ',
#   'PROPRIÁ',
#   'ARACAJU',
#   'SIMÃO DIAS',
#   'ITABAIANA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PORTO',
#   'ATALAIA',
#   'URUBU',
#   'GRACCHO CARDOSO',
#   'RIACHUELO',
#   'CONTORNO',
#   'CONTORNO',
#   'MOITA BONITA',
#   'URUBU',
#   'PROPRIÁ',
#   'PROPRIÁ',
#   'SÃO CRISTOVÃO',
#   'CAJAÍBA',
#   'PROPRIÁ',
#   'ITABAIANA',
#   'GRACCHO CARDOSO',
#   'SÃO CRISTOVÃO',
#   'PROPRIÁ',
#   'ITAPORANGA',
#   'ATALAIA',
#   'XINGÓ',
#   'ITAPORANGA',
#   'NOSSA SENHORA DAS DORES',
#   'URUBU',
#   'FREI PAULO',
#   'RIACHUELO',
#   'ARACAJU',
#   'ARACAJU',
#   'FREI PAULO',
#   'MONTE ALEGRE',
#   'MOITA BONITA',
#   'TAIÇOCA',
#   'SIMÃO DIAS',
#   'MOSQUEIRO',
#   'CARRAPICHO',
#   'PORTO',
#   'MOSQUEIRO',
#   'SÃO CRISTOVÃO',
#   'MOSQUEIRO',
#   'POÇO VERDE',
#   'PROPRIÁ',
#   'CAJAÍBA',
#   'XINGÓ',
#   'NOSSA SENHORA DA GLÓRIA',
#   'MOSQUEIRO',
#   'SÃO CRISTOVÃO',
#   'PORTO',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'RIACHUELO',
#   'XINGÓ',
#   'XINGÓ',
#   'ITABAIANA',
#   'CONTORNO',
#   'FREI PAULO',
#   'MARUIM',
#   'ATALAIA',
#   'NOSSA SENHORA DAS DORES',
#   'FREI PAULO',
#   'PROPRIÁ',
#   'MARUIM',
#   'LAGARTO',
#   'MONTE ALEGRE',
#   'MOITA BONITA',
#   'PROPRIÁ',
#   'XINGÓ',
#   'SALGADO',
#   'ATALAIA',
#   'URUBU',
#   'LAGARTO',
#   'ATALAIA',
#   'CONTORNO',
#   'CONTORNO',
#   'FREI PAULO',
#   'FREI PAULO',
#   'ATALAIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ATALAIA',
#   'MARUIM',
#   'CARRAPICHO',
#   'MOSQUEIRO',
#   'CARRAPICHO',
#   'CABRITA',
#   'FREI PAULO',
#   'FREI PAULO',
#   'ITABAIANA',
#   'ITABAIANA',
#   'MOSQUEIRO',
#   'URUBU',
#   'GRACCHO CARDOSO',
#   'ATALAIA',
#   'ATALAIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'MOITA BONITA',
#   'MOITA BONITA',
#   'XINGÓ',
#   'LAGARTO',
#   'CARRAPICHO',
#   'SIMÃO DIAS',
#   'PORTO DA FOLHA',
#   'PROPRIÁ',
#   'SÃO CRISTOVÃO',
#   'FREI PAULO',
#   'CAJAÍBA',
#   'ITAPORANGA',
#   'ARACAJU',
#   'ARACAJU',
#   'ITABAIANA',
#   'PORTO',
#   'RIACHUELO',
#   'URUBU',
#   'ARACAJU',
#   'PORTO',
#   'PROPRIÁ',
#   'MONTE ALEGRE',
#   'PROPRIÁ',
#   'FREI PAULO',
#   'ITABAIANA',
#   'ITABAIANA',
#   'ATALAIA',
#   'LAGARTO',
#   'CAJAÍBA',
#   'MARUIM',
#   'PORTO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'FREI PAULO',
#   'TAIÇOCA',
#   'MOSQUEIRO',
#   'TAIÇOCA',
#   'CARMÓPOLIS',
#   'XINGÓ',
#   'CARMÓPOLIS',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'NOSSA SENHORA DAS DORES',
#   'ITABAIANA',
#   'POÇO VERDE',
#   'GRAGERU',
#   'GRAGERU',
#   'RIACHUELO',
#   'XINGÓ',
#   'CARRAPICHO',
#   'MOSQUEIRO',
#   'FREI PAULO',
#   'LAGARTO',
#   'ATALAIA',
#   'MOITA BONITA',
#   'SIMÃO DIAS',
#   'NOSSA SENHORA DAS DORES',
#   'SALGADO',
#   'SALGADO',
#   'NOSSA SENHORA DAS DORES',
#   'CARRAPICHO',
#   'ARACAJU',
#   'ATALAIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ITABAIANA',
#   'LAGARTO',
#   'GRAGERU',
#   'CONTORNO',
#   'CARRAPICHO',
#   'ITAPORANGA',
#   'ITAPORANGA',
#   'ATALAIA',
#   'ATALAIA',
#   'GRAGERU',
#   'CABRITA',
#   'POÇO VERDE',
#   'ITABAIANA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'CONTORNO',
#   'POÇO VERDE',
#   'GRACCHO CARDOSO',
#   'ITABAIANA',
#   'ATALAIA',
#   'POÇO VERDE',
#   'CARRAPICHO',
#   'ATALAIA',
#   'RIACHUELO',
#   'ITABAIANA',
#   'URUBU',
#   'MARUIM',
#   'SALGADO',
#   'POÇO VERDE',
#   'POÇO VERDE',
#   'MONTE ALEGRE',
#   'SÃO CRISTOVÃO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'FREI PAULO',
#   'PORTO DA FOLHA',
#   'FREI PAULO',
#   'CARRAPICHO',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'TAIÇOCA',
#   'TAIÇOCA',
#   'FREI PAULO',
#   'ITAPORANGA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'TAIÇOCA',
#   'MONTE ALEGRE',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PORTO',
#   'PORTO',
#   'URUBU',
#   'PORTO DA FOLHA',
#   'SALGADO',
#   'MOITA BONITA',
#   'MOSQUEIRO',
#   'PORTO DA FOLHA',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'SALGADO',
#   'MONTE ALEGRE',
#   'CABRITA',
#   'MONTE ALEGRE',
#   'MARUIM',
#   'XINGÓ',
#   'LAGARTO',
#   'TAIÇOCA',
#   'PROPRIÁ',
#   'PROPRIÁ',
#   'SALGADO',
#   'URUBU',
#   'RIACHUELO',
#   'PORTO DA FOLHA',
#   'LAGARTO',
#   'CAJAÍBA',
#   'SIMÃO DIAS',
#   'PORTO DA FOLHA',
#   'PORTO DA FOLHA',
#   'PROPRIÁ',
#   'GRACCHO CARDOSO',
#   'TAIÇOCA',
#   'ITABAIANA',
#   'ITABAIANA',
#   'RIACHUELO',
#   'SALGADO',
#   'ITAPORANGA',
#   'CAJAÍBA',
#   'MOITA BONITA',
#   'ITAPORANGA',
#   'PROPRIÁ',
#   'GRACCHO CARDOSO',
#   'ITABAIANA',
#   'MOITA BONITA',
#   'MONTE ALEGRE',
#   'PORTO DA FOLHA',
#   'TAIÇOCA',
#   'ARACAJU',
#   'ARACAJU',
#   'ARACAJU',
#   'CABRITA',
#   'GRAGERU',
#   'PORTO DA FOLHA',
#   'GRAGERU',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'PROPRIÁ',
#   'MOSQUEIRO',
#   'PORTO DA FOLHA',
#   'CONTORNO',
#   'FREI PAULO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'SIMÃO DIAS',
#   'CAJAÍBA',
#   'MONTE ALEGRE',
#   'SIMÃO DIAS',
#   'TAIÇOCA',
#   'MARUIM',
#   'CABRITA',
#   'PORTO',
#   'ITAPORANGA',
#   'MOSQUEIRO',
#   'URUBU',
#   'ATALAIA',
#   'ARACAJU',
#   'MOSQUEIRO',
#   'ITAPORANGA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'XINGÓ',
#   'PROPRIÁ',
#   'POÇO VERDE',
#   'NOSSA SENHORA DAS DORES',
#   'GRAGERU',
#   'ARACAJU',
#   'ARACAJU',
#   'PROPRIÁ',
#   'NOSSA SENHORA DA GLÓRIA',
#   'FREI PAULO',
#   'SIMÃO DIAS',
#   'PROPRIÁ',
#   'GRACCHO CARDOSO',
#   'LAGARTO',
#   'LAGARTO',
#   'PROPRIÁ',
#   'XINGÓ',
#   'SÃO CRISTOVÃO',
#   'SIMÃO DIAS',
#   'CONTORNO',
#   'CONTORNO',
#   'PORTO DA FOLHA',
#   'FREI PAULO',
#   'SIMÃO DIAS',
#   'PORTO',
#   'PROPRIÁ',
#   'ARACAJU',
#   'ARACAJU',
#   'ARACAJU',
#   'LAGARTO',
#   'ATALAIA',
#   'ATALAIA',
#   'ARACAJU',
#   'ARACAJU',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ARACAJU',
#   'ARACAJU',
#   'ARACAJU',
#   'FREI PAULO',
#   'PROPRIÁ',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'SIMÃO DIAS',
#   'ITABAIANA',
#   'RIACHUELO',
#   'ARACAJU',
#   'TAIÇOCA',
#   'URUBU',
#   'URUBU',
#   'GRACCHO CARDOSO',
#   'PROPRIÁ',
#   'XINGÓ',
#   'PROPRIÁ',
#   'MARUIM',
#   'SALGADO',
#   'FREI PAULO',
#   'URUBU',
#   'GRACCHO CARDOSO',
#   'ITABAIANA',
#   'ARACAJU',
#   'NOSSA SENHORA DAS DORES',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PORTO DA FOLHA',
#   'PORTO DA FOLHA',
#   'ITABAIANA',
#   'ITAPORANGA',
#   'CAJAÍBA',
#   'MOITA BONITA',
#   'PROPRIÁ',
#   'LAGARTO',
#   'CABRITA',
#   'ITABAIANA',
#   'MONTE ALEGRE',
#   'SÃO CRISTOVÃO',
#   'NOSSA SENHORA DAS DORES',
#   'NOSSA SENHORA DAS DORES',
#   'PORTO DA FOLHA',
#   'PORTO DA FOLHA',
#   'MOITA BONITA',
#   'SÃO CRISTOVÃO',
#   'GRACCHO CARDOSO',
#   'MONTE ALEGRE',
#   'PORTO',
#   'ITABAIANA',
#   'RIACHUELO',
#   'SIMÃO DIAS',
#   'LAGARTO',
#   'SERIGY',
#   'ATALAIA',
#   'SALGADO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'POÇO VERDE',
#   'MOITA BONITA',
#   'GRACCHO CARDOSO',
#   'URUBU',
#   'NOSSA SENHORA DA GLÓRIA',
#   'CAJAÍBA',
#   'CARMÓPOLIS',
#   'GRACCHO CARDOSO',
#   'CARRAPICHO',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'MOSQUEIRO',
#   'PROPRIÁ',
#   'SÃO CRISTOVÃO',
#   'ATALAIA',
#   'MOSQUEIRO',
#   'ATALAIA',
#   'ITABAIANA',
#   'ATALAIA',
#   'RIACHUELO',
#   'ATALAIA',
#   'ARACAJU',
#   'TAIÇOCA',
#   'MOSQUEIRO',
#   'CABRITA',
#   'LAGARTO',
#   'MOSQUEIRO',
#   'SÃO CRISTOVÃO',
#   'MOITA BONITA',
#   'PORTO',
#   'ARACAJU',
#   'URUBU',
#   'PROPRIÁ',
#   'TAIÇOCA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'TAIÇOCA',
#   'FREI PAULO',
#   'PORTO',
#   'CARRAPICHO',
#   'ATALAIA',
#   'POÇO VERDE',
#   'ATALAIA',
#   'GRAGERU',
#   'CARMÓPOLIS',
#   'SIMÃO DIAS',
#   'URUBU',
#   'POÇO VERDE',
#   'GRACCHO CARDOSO',
#   'ATALAIA',
#   'RIACHUELO',
#   'GRAGERU',
#   'PORTO DA FOLHA',
#   'GRACCHO CARDOSO',
#   'ITABAIANA',
#   'URUBU',
#   'URUBU',
#   'SERIGY',
#   'NOSSA SENHORA DAS DORES',
#   'NOSSA SENHORA DAS DORES',
#   'CARRAPICHO',
#   'MARUIM',
#   'PORTO DA FOLHA',
#   'CARMÓPOLIS',
#   'ATALAIA',
#   'SALGADO',
#   'SALGADO',
#   'SALGADO',
#   'SALGADO',
#   'SALGADO',
#   'PROPRIÁ',
#   'CABRITA',
#   'PORTO',
#   'PROPRIÁ',
#   'SIMÃO DIAS',
#   'FREI PAULO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PROPRIÁ',
#   'MARUIM',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'GRACCHO CARDOSO',
#   'GRAGERU',
#   'LAGARTO',
#   'ITABAIANA',
#   'PROPRIÁ',
#   'CAJAÍBA',
#   'URUBU',
#   'GRACCHO CARDOSO',
#   'CARRAPICHO',
#   'ITABAIANA',
#   'ITABAIANA',
#   'PORTO DA FOLHA',
#   'GRACCHO CARDOSO',
#   'URUBU',
#   'FREI PAULO',
#   'ATALAIA',
#   'SERIGY',
#   'GRACCHO CARDOSO',
#   'ITABAIANA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'CARRAPICHO',
#   'LAGARTO',
#   'ITABAIANA',
#   'PROPRIÁ',
#   'MOSQUEIRO',
#   'MARUIM',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PROPRIÁ',
#   'MOSQUEIRO',
#   'ITAPORANGA',
#   'MOSQUEIRO',
#   'GRAGERU',
#   'MOSQUEIRO',
#   'MARUIM',
#   'MARUIM',
#   'MOITA BONITA',
#   'NOSSA SENHORA DAS DORES',
#   'PORTO',
#   'PROPRIÁ',
#   'MOITA BONITA',
#   'ARACAJU',
#   'NOSSA SENHORA DA GLÓRIA',
#   'RIACHUELO',
#   'FREI PAULO',
#   'TAIÇOCA',
#   'GRACCHO CARDOSO',
#   'ITAPORANGA',
#   'CARRAPICHO',
#   'CARRAPICHO',
#   'PROPRIÁ',
#   'ITAPORANGA',
#   'GRACCHO CARDOSO',
#   'CONTORNO',
#   'ATALAIA',
#   'PROPRIÁ',
#   'CARRAPICHO',
#   'PROPRIÁ',
#   'FREI PAULO',
#   'GRACCHO CARDOSO',
#   'CARMÓPOLIS',
#   'LAGARTO',
#   'GRAGERU',
#   'NOSSA SENHORA DAS DORES',
#   'CABRITA',
#   'CABRITA',
#   'CARMÓPOLIS',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DAS DORES',
#   'CABRITA',
#   'CABRITA',
#   'ARACAJU',
#   'PROPRIÁ',
#   'POÇO VERDE',
#   'ITAPORANGA',
#   'ITABAIANA',
#   'PROPRIÁ',
#   'ATALAIA',
#   'RIACHUELO',
#   'TAIÇOCA',
#   'MOSQUEIRO',
#   'PROPRIÁ',
#   'CARRAPICHO',
#   'NOSSA SENHORA DAS DORES',
#   'SERIGY',
#   'ARACAJU',
#   'ARACAJU',
#   'NOSSA SENHORA DAS DORES',
#   'PROPRIÁ',
#   'PROPRIÁ',
#   'GRAGERU',
#   'PROPRIÁ',
#   'ITABAIANA',
#   'PORTO DA FOLHA',
#   'ITABAIANA',
#   'POÇO VERDE',
#   'LAGARTO',
#   'ATALAIA',
#   'POÇO VERDE',
#   'ITABAIANA',
#   'MOITA BONITA',
#   'RIACHUELO',
#   'PORTO',
#   'CONTORNO',
#   'PROPRIÁ',
#   'SÃO CRISTOVÃO',
#   'SÃO CRISTOVÃO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'URUBU',
#   'MONTE ALEGRE',
#   'MONTE ALEGRE',
#   'URUBU',
#   'PROPRIÁ',
#   'PROPRIÁ',
#   'MOSQUEIRO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DAS DORES',
#   'ITAPORANGA',
#   'ITABAIANA',
#   'TAIÇOCA',
#   'ITAPORANGA',
#   'TAIÇOCA',
#   'URUBU',
#   'CONTORNO',
#   'CONTORNO',
#   'FREI PAULO',
#   'CONTORNO',
#   'MOSQUEIRO',
#   'ATALAIA',
#   'CAJAÍBA',
#   'TAIÇOCA',
#   'TAIÇOCA',
#   'ITAPORANGA',
#   'ATALAIA',
#   'ATALAIA',
#   'TAIÇOCA',
#   'CABRITA',
#   'RIACHUELO',
#   'LAGARTO',
#   'URUBU',
#   'URUBU',
#   'ATALAIA',
#   'ATALAIA',
#   'CAJAÍBA',
#   'CAJAÍBA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'PROPRIÁ',
#   'CABRITA',
#   'CONTORNO',
#   'URUBU',
#   'SERIGY',
#   'MOSQUEIRO',
#   'XINGÓ',
#   'PORTO',
#   'ATALAIA',
#   'CONTORNO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'RIACHUELO',
#   'SÃO CRISTOVÃO',
#   'RIACHUELO',
#   'GRACCHO CARDOSO',
#   'MARUIM',
#   'LAGARTO',
#   'CAJAÍBA',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'GRACCHO CARDOSO',
#   'MOSQUEIRO',
#   'GRACCHO CARDOSO',
#   'XINGÓ',
#   'PORTO DA FOLHA',
#   'NOSSA SENHORA DAS DORES',
#   'ITAPORANGA',
#   'SALGADO',
#   'MOSQUEIRO',
#   'GRAGERU',
#   'MARUIM',
#   'MARUIM',
#   'PORTO DA FOLHA',
#   'SERIGY',
#   'PROPRIÁ',
#   'SIMÃO DIAS',
#   'MONTE ALEGRE',
#   'ARACAJU',
#   'FREI PAULO',
#   'PROPRIÁ',
#   'NOSSA SENHORA DA GLÓRIA',
#   'XINGÓ',
#   'CONTORNO',
#   'LAGARTO',
#   'NOSSA SENHORA DA GLÓRIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'ATALAIA',
#   'GRAGERU',
#   'SALGADO',
#   'XINGÓ',
#   'SALGADO',
#   'SALGADO',
#   'ITABAIANA',
#   'URUBU',
#   'RIACHUELO',
#   'SÃO CRISTOVÃO',
#   'TAIÇOCA',
#   'ARACAJU',
#   'ARACAJU',
#   'ATALAIA',
#   'CARMÓPOLIS',
#   'ITAPORANGA',
#   'ITAPORANGA',
#   'SÃO CRISTOVÃO',
#   'RIACHUELO',
#   'ITAPORANGA',
#   'POÇO VERDE',
#   'XINGÓ',
#   'MOSQUEIRO',
#   'MONTE ALEGRE',
#   'CARRAPICHO',
#   'ITAPORANGA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'RIACHUELO',
#   'ITAPORANGA',
#   'ITAPORANGA',
#   'SÃO CRISTOVÃO',
#   'MONTE ALEGRE',
#   'LAGARTO',
#   'ATALAIA',
#   'ATALAIA',
#   'NOSSA SENHORA DA GLÓRIA',
#   'SIMÃO DIAS',
#   'URUBU',
#   'SÃO CRISTOVÃO',
#   'CAJAÍBA',
#   'ITAPORANGA',
#   'ITAPORANGA',
#   'CARRAPICHO',
#   'CAJAÍBA',
#   'RIACHUELO',
#   'ATALAIA',
#   'CAJAÍBA',
#   'URUBU',
#   'LAGARTO',
#   'SIMÃO DIAS',
#   'SÃO CRISTOVÃO',
#   'MOSQUEIRO',
#   'PROPRIÁ',
#   'SALGADO',
#   'SIMÃO DIAS',
#   ...]}

# %%
with open("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/CONJUNTOS_ENERGISA_SERGIPE.json", 'w') as f:
  json.dump(interrupcoes_dict, f)
