# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemunarol/UFF-Projects/blob/main/src/cemig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Filtra os conjunto somente da Distribuidora Cemig que tem área de concessão em parte do Rio de Janeiro (considerando 2023) para o teste da inferencia do modelo

# %%
import csv
import pandas as pd
import os
import json

pd.set_option('display.max_columns', None)

# Conecta o serviço com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Raiz
! ls '/content/drive/MyDrive/Mestrado/Ordens_servico/'
# Out:
# 'Apresentacoes Andamento'   Dissertaçao_v1.docx     Ordens_servico
# 'Definição Problema.gdoc'   Dissertacao_v2.docx    'Tese Latex'
#  Dissertaçao.docx	   'Doc Dissertação.gdoc'   Tese.pdf
#  Dissertaçao_v0.docx	    Doc.gdoc

# %% [markdown]
# # Preprocess

# %%
year = 2022

# %%
interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))
# Out:
# <ipython-input-5-39954c25d839>:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))

# %%
interrupcoes
# Out:
#          Unnamed: 0.1  Unnamed: 0        _id DatGeracaoConjuntoDados  \
# 0                   0           0  2000001.0              2023-05-26
# 1                   1           1  2000002.0              2023-05-26
# 2                   2           2  2000003.0              2023-05-26
# 3                   3           3  2000004.0              2023-05-26
# 4                   4           4  2000005.0              2023-05-26
# ...               ...         ...        ...                     ...
# 8487227        447227      447227  8467228.0              2023-05-26
# 8487228        447228      447228  8467229.0              2023-05-26
# 8487229        447229      447229  8467230.0              2023-05-26
# 8487230        447230      447230  8467231.0              2023-05-26
# 8487231        447231      447231  8467232.0              2023-05-26
#
#         DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 0                           Pompeia 1                    GTU03
# ...

# %%
interrupcoes = interrupcoes[interrupcoes.NomAgenteRegulado.str.contains('CEMIG')]

# %%
interrupcoes_array = interrupcoes.DscConjuntoUnidadeConsumidora.values

# %%
interrupcoes_dict = {}
interrupcoes_dict["conjuntos"] = list(interrupcoes_array)
interrupcoes_dict
# Out:
# {'conjuntos': ['Contagem 3',
#   'Governador Valadares 2',
#   'Contagem 3',
#   'Carmo do Rio Claro',
#   'Uberaba 3',
#   'UH Itutinga',
#   'Igarape 1',
#   'Divinópolis 1',
#   'Nova Lima 1',
#   'BH Bonsucesso',
#   'Barroso 3',
#   'Botelhos',
#   'BH Sion',
#   'Liberdade',
#   'Itajubá 1',
#   'Liberdade',
#   'Liberdade',
#   'Liberdade',
#   'Ipatinga 2',
#   'Montes Claros 2',
#   'Três Corações 1',
#   'Contagem 3',
#   'Pains 2',
#   'Sabará 1',
#   'Sacramento 2',
#   'Neves 2',
#   'Boa Esperança 2',
#   'Governador Valadares 2',
#   'Lavras 2',
#   'Lavras 2',
#   'Lavras 2',
#   'Lavras 2',
#   'Itaobim',
#   'Corinto 1',
#   'Corinto 1',
#   'Janaúba 1',
#   'BH Jatobá',
#   'BH Serra Verde',
#   'Carangola',
#   'Formiga',
#   'Formiga',
#   'Santa Luzia 4',
#   'Três Pontas 1',
#   'Lagoa da Prata 1',
#   'Passos 1',
#   'Uberaba 1',
#   'Machado 2',
#   'Machado 2',
#   'Machado 2',
#   'Machado 2',
#   'Machado 2',
#   'Betim 3',
#   'São Francisco 4',
# ...

# %%
with open("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/CONJUNTOS_CEMIG.json", 'w') as f:
  json.dump(interrupcoes_dict, f)
