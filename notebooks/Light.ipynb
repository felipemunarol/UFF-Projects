# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemunarol/UFF-Projects/blob/main/src/Light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Filtra os conjunto somente da Distribuidora Light que tem área de concessão em parte do Rio de Janeiro (considerando 2023) para o teste da inferencia do modelo

# %%
import csv
import pandas as pd
import os
import json

pd.set_option('display.max_columns', None)

# Conecta o serviço com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Raiz
! ls '/content/drive/MyDrive/Mestrado/Ordens_servico/'
# Out:
# 'Apresentacoes Andamento'   Dissertaçao_v0.docx     Ordens_servico
# 'Definição Problema.gdoc'  'Doc Dissertação.gdoc'  'Tese Latex'
#  Dissertaçao.docx	    Doc.gdoc		    Tese.pdf

# %% [markdown]
# # Preprocess

# %%
year = 2022

# %%
interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))
# Out:
# <ipython-input-4-39954c25d839>:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interrupcoes = pd.read_csv("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/test_interrupcoes_collect_ckan_{}.csv".format(year))

# %%
interrupcoes = interrupcoes[interrupcoes.NomAgenteRegulado.str.contains('LIGHT')]

# %%
interrupcoes
# Out:
#          Unnamed: 0.1  Unnamed: 0        _id DatGeracaoConjuntoDados  \
# 3125460         85460       85460  3105461.0              2023-05-26
# 3125461         85461       85461  3105462.0              2023-05-26
# 3125462         85462       85462  3105463.0              2023-05-26
# 3125463         85463       85463  3105464.0              2023-05-26
# 3125464         85464       85464  3105465.0              2023-05-26
# ...               ...         ...        ...                     ...
# 3391438        351438      351438  3371439.0              2023-05-26
# 3391439        351439      351439  3371440.0              2023-05-26
# 3391440        351440      351440  3371441.0              2023-05-26
# 3391441        351441      351441  3371442.0              2023-05-26
# 3391442        351442      351442  3371443.0              2023-05-26
#
#         DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 3125460        CENTENARIO AEREO MT/MT                     2493
# 3125461        CENTENARIO AEREO MT/MT                     2493
# 3125462                       RECREIO                     1145
# 3125463                    ARI FRANCO                      738
# 3125464     SANTA CECILIA AEREO MT/MT                     2343
# ...                               ...                      ...
# 3391438                      ALVORADA                     2173
# 3391439                      ALVORADA                     2173
# 3391440                      ALVORADA                     2173
# 3391441                      ALVORADA                     2173
# 3391442                      ALVORADA                     2173
#
#         DscSubestacaoDistribuicao NumOrdemInterrupcao DscTipoInterrupcao  \
# 3125460                  18520335            940266-1     Não Programada
# 3125461                  18520335            940264-1     Não Programada
# 3125462                 132097219            929088-1     Não Programada
# 3125463                  18520461            929038-1     Não Programada
# 3125464                  18520641            928946-1     Não Programada
# ...                           ...                 ...                ...
# 3391438                  10385943           5168591-5     Não Programada
# 3391439                  10385943           5168591-6     Não Programada
# 3391440                  10385943           5168591-2     Não Programada
# 3391441                  10385943           5168591-7     Não Programada
# 3391442                  10385943           5168591-3     Não Programada
#
#          IdeMotivoInterrupcao DatInicioInterrupcao    DatFimInterrupcao  \
# 3125460                   0.0  2022-01-01 00:04:14  2022-01-01 00:44:19
# 3125461                   0.0  2022-01-01 00:04:14  2022-01-01 00:44:19
# 3125462                   0.0  2022-01-01 00:23:00  2022-01-01 02:43:38
# 3125463                   0.0  2022-01-01 00:28:00  2022-01-01 02:12:05
# 3125464                   0.0  2022-01-01 00:30:53  2022-01-01 00:59:29
# ...                       ...                  ...                  ...
# 3391438                   0.0  2022-12-31 23:47:03  2023-01-01 01:05:00
# 3391439                   0.0  2022-12-31 23:47:03  2023-01-01 01:05:00
# 3391440                   0.0  2022-12-31 23:47:03  2023-01-01 00:20:00
# 3391441                   0.0  2022-12-31 23:47:03  2023-01-01 01:07:00
# 3391442                   0.0  2022-12-31 23:47:03  2023-01-01 00:35:00
#
#                                  DscFatoGeradorInterrupcao  NumNivelTensao  \
# 3125460  INTERNA - NÃO PROGRAMADA - MEIO AMBIENTE - DES...         13800.0
# 3125461  INTERNA - NÃO PROGRAMADA - MEIO AMBIENTE - DES...           127.0
# 3125462  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...           127.0
# 3125463  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...           127.0
# 3125464  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...           127.0
# ...                                                    ...             ...
# 3391438  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...         13800.0
# 3391439  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...         13800.0
# 3391440  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...         13800.0
# 3391441  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...         13800.0
# 3391442  INTERNA - NÃO PROGRAMADA - PRÓPRIAS DO SISTEMA...         13800.0
#
#          NumUnidadeConsumidora  NumConsumidorConjunto  NumAno  \
# 3125460                   10.0                23736.0  2022.0
# 3125461                    2.0                23736.0  2022.0
# 3125462                    1.0                58446.0  2022.0
# 3125463                  127.0                60222.0  2022.0
# 3125464                    1.0                29303.0  2022.0
# ...                        ...                    ...     ...
# 3391438                  183.0                28760.0  2022.0
# 3391439                   74.0                28760.0  2022.0
# 3391440                 1267.0                28760.0  2022.0
# 3391441                  242.0                28760.0  2022.0
# 3391442                  344.0                28760.0  2022.0
#
#                           NomAgenteRegulado             SigAgente  \
# 3125460  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3125461  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3125462  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3125463  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3125464  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# ...                                     ...                   ...
# 3391438  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3391439  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3391440  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3391441  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
# 3391442  LIGHT SERVIÇOS DE ELETRICIDADE S A  LIGHT
#
#            NumCPFCNPJ
# 3125460  6.044444e+13
# 3125461  6.044444e+13
# 3125462  6.044444e+13
# 3125463  6.044444e+13
# 3125464  6.044444e+13
# ...               ...
# 3391438  6.044444e+13
# 3391439  6.044444e+13
# 3391440  6.044444e+13
# 3391441  6.044444e+13
# 3391442  6.044444e+13
#
# [265983 rows x 20 columns]

# %%
interrupcoes_array = interrupcoes.DscConjuntoUnidadeConsumidora.values

# %%
interrupcoes_dict = {}
interrupcoes_dict["conjuntos"] = list(interrupcoes_array)
interrupcoes_dict
# Out:
# {'conjuntos': ['CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'RECREIO',
#   'ARI FRANCO',
#   'SANTA CECILIA AEREO MT/MT',
#   'COMENDADOR SOARES',
#   'CARMARI',
#   'PIEDADE',
#   'VOLTA REDONDA AEREO MT/MT',
#   'ITAGUAI',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CARMARI',
#   'ROCHA FREIRE AEREO MT/MT',
#   'ROCHA FREIRE AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'RETIRO',
#   'CENTENARIO AEREO MT/MT',
#   'CACHAMBI AEREO',
#   'VIGARIO GERAL AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'ROCHA FREIRE AEREO AT/MT',
#   'ROCHA FREIRE AEREO AT/MT',
#   'ROCHA FREIRE AEREO AT/MT',
#   'ROCHA FREIRE AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'GUADALUPE AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CACHAMBI AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SAPUCAIA',
#   'BRISA MAR',
#   'BRISA MAR',
#   'PAVUNA',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'BRISA MAR',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'RIO COMPRIDO AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'BRISA MAR',
#   'BRISA MAR',
#   'BRISA MAR',
#   'CENTENARIO AEREO AT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'DEMOCRATICOS AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'ITAGUAI',
#   'BRISA MAR',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'BRISA MAR',
#   'BRISA MAR',
#   'COLEGIO AEREO',
#   'CACHAMBI AEREO',
#   'CACHAMBI AEREO',
#   'CACHAMBI AEREO',
#   'CACHAMBI AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'ITAGUAI',
#   'SAMARITANO SUBTERRANEO',
#   'ITAGUAI',
#   'ITAGUAI',
#   'BRISA MAR',
#   'FONTINELE',
#   'ROCHA FREIRE AEREO AT/MT',
#   'CAXIAS AEREO',
#   'PIEDADE',
#   'CAMARA',
#   'NOVA IGUACU',
#   'CENTENARIO AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'LEOPOLDO AEREO',
#   'VIGARIO',
#   'FONTINELE',
#   'SANTA CECILIA AEREO MT/MT',
#   'PORTA DAGUA AEREO',
#   'PORTA DAGUA AEREO',
#   'ITAGUAI',
#   'BARRA AEREO',
#   'BARRA AEREO',
#   'FREI CANECA AEREO',
#   'CAMPO MARTE AEREO',
#   'CAMPO MARTE AEREO',
#   'JABOATAO AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'CAMARA',
#   'CENTENARIO AEREO MT/MT',
#   'TURIACU',
#   'SARAPUI',
#   'BARRA AEREO',
#   'FONTINELE',
#   'RECREIO',
#   'SAPUCAIA',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'SAUDADE',
#   'PADRE MIGUEL',
#   'SARAPUI',
#   'ARI FRANCO',
#   'SEROPEDICA AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SAPUCAIA',
#   'CACHAMBI AEREO',
#   'CASCADURA AEREO',
#   'SANTA CECILIA AEREO AT/MT',
#   'CAXIAS AEREO',
#   'SEROPEDICA AEREO',
#   'SAPUCAIA',
#   'VIGARIO',
#   'PORTA DAGUA AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'ITAGUAI',
#   'CENTENARIO AEREO AT/MT',
#   'RECREIO',
#   'RECREIO',
#   'CENTENARIO AEREO AT/MT',
#   'PEDRO ERNESTO AEREO',
#   'ITAGUAI',
#   'PORTA DAGUA AEREO',
#   'PADRE MIGUEL',
#   'CASCADURA AEREO',
#   'CAMARA',
#   'FONTINELE',
#   'COELHO DA ROCHA',
#   'CENTENARIO AEREO MT/MT',
#   'COLEGIO AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'SAPUCAIA',
#   'SARAPUI',
#   'NOVA IGUACU',
#   'VOLTA REDONDA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'VIGARIO',
#   'CACHAMBI AEREO',
#   'COELHO DA ROCHA',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'RETIRO',
#   'MERITI',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'JABOATAO AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO AT/MT',
#   'COMENDADOR SOARES',
#   'NOVA IGUACU',
#   'CENTENARIO AEREO AT/MT',
#   'SARAPUI',
#   'TRES RIOS AEREO AT/MT',
#   'ROSALI',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'GUANABARA AEREO',
#   'COSMOS',
#   'MATO ALTO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'COLEGIO AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'COELHO DA ROCHA',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'BOTAFOGO AEREO URBANO',
#   'PADRE MIGUEL',
#   'MATO ALTO',
#   'CAXIAS AEREO',
#   'SAPUCAIA',
#   'VOLTA REDONDA AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'VIGARIO',
#   'SEROPEDICA AEREO',
#   'SAUDADE',
#   'COSMOS',
#   'COSMOS',
#   'URUGUAI AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'MENA BARRETO AEREO',
#   'ROSALI',
#   'ROSALI',
#   'SANTA CECILIA AEREO AT/MT',
#   'GUANABARA AEREO',
#   'COELHO DA ROCHA',
#   'NOVA IGUACU',
#   'CAXIAS AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'MATO ALTO',
#   'CENTENARIO AEREO MT/MT',
#   'PADRE MIGUEL',
#   'CENTENARIO AEREO MT/MT',
#   'SAPUCAIA',
#   'CENTENARIO AEREO AT/MT',
#   'FONTINELE',
#   'QUEIMADOS AEREO',
#   'MATO ALTO',
#   'GUANABARA AEREO',
#   'BRISA MAR',
#   'PIEDADE',
#   'BARRA SUBTERRANEO',
#   'GUADALUPE AEREO',
#   'SANTA CLARA AEREO',
#   'MATO ALTO',
#   'WASHINGTON LUIS AEREO',
#   'ARI FRANCO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'ROSALI',
#   'COLEGIO AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'TRIAGEM AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'QUEIMADOS AEREO',
#   'ROSALI',
#   'TURIACU',
#   'SANTO ANTONIO SUBTERRANEO',
#   'SANTO ANTONIO SUBTERRANEO',
#   'TRES RIOS AEREO MT/MT',
#   'SAO JOAO',
#   'AREIA BRANCA AEREO',
#   'MERITI',
#   'SEROPEDICA AEREO',
#   'LEME AEREO URBANO',
#   'TROVAO AEREO',
#   'ITAPEBA AEREO URBANO',
#   'RETIRO',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'INMETRO',
#   'RETIRO',
#   'COMENDADOR SOARES',
#   'VIGARIO GERAL AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'PIEDADE',
#   'PORTA DAGUA AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'BARRA AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'BARRA AEREO',
#   'RETIRO',
#   'ESPERANCA AEREO AT/MT',
#   'CARMARI',
#   'CARMARI',
#   'ESPERANCA AEREO MT/MT',
#   'RETIRO',
#   'BARRA AEREO',
#   'BARRA SUBTERRANEO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CACHAMORRA',
#   'QUEIMADOS AEREO',
#   'VILA VALQUEIRE',
#   'CENTENARIO AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CACHAMORRA',
#   'MATURACA AEREO',
#   'MENA BARRETO AEREO',
#   'BRISA MAR',
#   'SEROPEDICA AEREO',
#   'SARAPUI',
#   'ITAPEBA SUBTERRANEO',
#   'ITAPEBA SUBTERRANEO',
#   'ITAPEBA AEREO URBANO',
#   'ITAPEBA AEREO URBANO',
#   'ITAPEBA AEREO URBANO',
#   'ITAPEBA AEREO URBANO',
#   'ITAGUAI',
#   'ESPERANCA AEREO MT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'GUANABARA AEREO',
#   'SEROPEDICA AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'SEROPEDICA AEREO',
#   'MATO ALTO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'PEDRO ERNESTO AEREO',
#   'RECREIO',
#   'SEROPEDICA AEREO',
#   'PIEDADE',
#   'ITAPEBA AEREO URBANO',
#   'ITAPEBA AEREO URBANO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'CURICICA AEREO',
#   'CURICICA AEREO',
#   'CURICICA AEREO',
#   'CURICICA AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'VIGARIO',
#   'BARRA AEREO',
#   'MATO ALTO',
#   'SANTA CECILIA AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'ALDEIA CAMPISTA',
#   'SANTA CECILIA AEREO AT/MT',
#   'CAMARA',
#   'CENTENARIO AEREO MT/MT',
#   'CASCADURA AEREO',
#   'VIGARIO',
#   'SANTA CECILIA AEREO MT/MT',
#   'PAVUNA',
#   'CENTENARIO AEREO AT/MT',
#   'SANTO ANTONIO AEREO URBANO',
#   'PIEDADE',
#   'SEROPEDICA AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'SAPUCAIA',
#   'SANTA CECILIA AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'VOLTA REDONDA AEREO MT/MT',
#   'TERRA NOVA AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SARAPUI',
#   'TRES RIOS AEREO AT/MT',
#   'TRES RIOS AEREO AT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'CAMARA',
#   'SAPUCAIA',
#   'ESPERANCA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SAPUCAIA',
#   'CURICICA AEREO',
#   'SAPUCAIA',
#   'SARAPUI',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'MATO ALTO',
#   'MENA BARRETO AEREO',
#   'VIGARIO',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'GUADALUPE AEREO',
#   'ITAPEBA AEREO URBANO',
#   'MENA BARRETO AEREO',
#   'TROVAO AEREO',
#   'VIGARIO GERAL AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'AREIA BRANCA AEREO',
#   'ROCHA FREIRE AEREO AT/MT',
#   'COELHO DA ROCHA',
#   'COELHO DA ROCHA',
#   'AREIA BRANCA AEREO',
#   'GUANABARA AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'PAVUNA',
#   'CASCADURA AEREO',
#   'MENA BARRETO AEREO',
#   'CURICICA AEREO',
#   'ROSALI',
#   'TERRA NOVA AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SARAPUI',
#   'COMENDADOR SOARES',
#   'FONTINELE',
#   'TRES RIOS AEREO MT/MT',
#   'AGUA GRANDE AEREO',
#   'ITAGUAI',
#   'BAEPENDI AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'COMENDADOR SOARES',
#   'TAQUARA AEREO',
#   'JABOATAO AEREO',
#   'SAPUCAIA',
#   'TAQUARA AEREO',
#   'COELHO DA ROCHA',
#   'VIGARIO',
#   'AREIA BRANCA AEREO',
#   'TRES RIOS AEREO AT/MT',
#   'TRES RIOS AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SAUDADE',
#   'MATO ALTO',
#   'SAPUCAIA',
#   'CASCADURA AEREO',
#   'AREIA BRANCA AEREO',
#   'CACHAMORRA',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SAPUCAIA',
#   'COMENDADOR SOARES',
#   'COMENDADOR SOARES',
#   'TURIACU',
#   'AREIA BRANCA AEREO',
#   'PADRE MIGUEL',
#   'CACHAMORRA',
#   'VOLTA REDONDA AEREO AT/MT',
#   'MERITI',
#   'TRES RIOS AEREO AT/MT',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SANTISSIMO AEREO',
#   'CACHAMORRA',
#   'BOTAFOGO AEREO URBANO',
#   'ZONA INDUSTRIAL',
#   'ESPERANCA AEREO AT/MT',
#   'AREIA BRANCA AEREO',
#   'TAQUARA AEREO',
#   'ROCHA FREIRE AEREO AT/MT',
#   'TAQUARA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'MERITI',
#   'RETIRO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'TAQUARA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'SAUDADE',
#   'TAQUARA AEREO',
#   'TRES RIOS AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'MATO ALTO',
#   'TRES RIOS AEREO MT/MT',
#   'QUEIMADOS AEREO',
#   'PADRE MIGUEL',
#   'VOLTA REDONDA AEREO AT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'CACHAMORRA',
#   'CENTENARIO AEREO MT/MT',
#   'AREIA BRANCA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CACHAMORRA',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'RETIRO',
#   'SEROPEDICA AEREO',
#   'ESPERANCA AEREO AT/MT',
#   'MATO ALTO',
#   'FONTINELE',
#   'FONTINELE',
#   'JABOATAO AEREO',
#   'NOVA IGUACU',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CACHAMORRA',
#   'SANTISSIMO AEREO',
#   'PADRE MIGUEL',
#   'MATO ALTO',
#   'TURIACU',
#   'TRES RIOS AEREO MT/MT',
#   'COSMOS',
#   'VIGARIO',
#   'TRES RIOS AEREO MT/MT',
#   'CAXIAS AEREO',
#   'PADRE MIGUEL',
#   'CENTENARIO AEREO MT/MT',
#   'BRISA MAR',
#   'ITAGUAI',
#   'ITAGUAI',
#   'PADRE MIGUEL',
#   'CAXIAS AEREO',
#   'PIEDADE',
#   'VOLTA REDONDA AEREO MT/MT',
#   'COLEGIO AEREO',
#   'ROCHA FREIRE AEREO MT/MT',
#   'SEROPEDICA AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'VILA VALQUEIRE',
#   'MATURACA AEREO',
#   'AGUA GRANDE AEREO',
#   'AGUA GRANDE AEREO',
#   'PADRE MIGUEL',
#   'VOLTA REDONDA AEREO MT/MT',
#   'TRES RIOS AEREO AT/MT',
#   'CASCADURA AEREO',
#   'PADRE MIGUEL',
#   'SAPUCAIA',
#   'NOVA IGUACU',
#   'CASCADURA AEREO',
#   'AREIA BRANCA AEREO',
#   'PAVUNA',
#   'BOCA DO MATO AEREO',
#   'CAMPO MARTE AEREO',
#   'CAMPO MARTE AEREO',
#   'CAMPO MARTE AEREO',
#   'BARRA 2',
#   'ALVORADA',
#   'ALVORADA',
#   'MERITI',
#   'BARRA AEREO',
#   'SAO CONRADO AEREO',
#   'FONTINELE',
#   'SANTISSIMO AEREO',
#   'LEOPOLDO AEREO',
#   'ROSALI',
#   'PADRE MIGUEL',
#   'CAMPO MARTE AEREO',
#   'GUADALUPE AEREO',
#   'CURICICA AEREO',
#   'ITAPEBA AEREO URBANO',
#   'CURICICA AEREO',
#   'ROSALI',
#   'CENTENARIO AEREO AT/MT',
#   'GOVERNADOR AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'SAO JOAO',
#   'ROSALI',
#   'COELHO DA ROCHA',
#   'PORTA DAGUA AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'VILA VALQUEIRE',
#   'AGUA GRANDE AEREO',
#   'VIGARIO',
#   'CENTENARIO AEREO MT/MT',
#   'ARI FRANCO',
#   'PORTA DAGUA AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'COLEGIO AEREO',
#   'MATO ALTO',
#   'MATO ALTO',
#   'TURIACU',
#   'SAPUCAIA',
#   'GUANABARA AEREO',
#   'VIGARIO GERAL AEREO',
#   'MATURACA AEREO',
#   'SAPUCAIA',
#   'CARMARI',
#   'VOLTA REDONDA AEREO MT/MT',
#   'COMENDADOR SOARES',
#   'ITAGUAI',
#   'BRISA MAR',
#   'SAUDADE',
#   'CENTENARIO AEREO MT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'COSMOS',
#   'CURICICA AEREO',
#   'COMENDADOR SOARES',
#   'VOLTA REDONDA AEREO MT/MT',
#   'RETIRO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'SAPUCAIA',
#   'CENTENARIO AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'CURICICA AEREO',
#   'SEROPEDICA AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'PORTA DAGUA AEREO',
#   'ROSALI',
#   'SANTA CECILIA AEREO MT/MT',
#   'SAPUCAIA',
#   'PORTA DAGUA AEREO',
#   'ROSALI',
#   'SARAPUI',
#   'FONTINELE',
#   'NOVA IGUACU',
#   'VIGARIO',
#   'VIGARIO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'PORTA DAGUA AEREO',
#   'BRAS DE PINA',
#   'SEROPEDICA AEREO',
#   'ITAPEBA AEREO URBANO',
#   'QUEIMADOS AEREO',
#   'CARMARI',
#   'PEDRO ERNESTO AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'SAPUCAIA',
#   'VIGARIO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'PEDRO ERNESTO AEREO',
#   'QUEIMADOS AEREO',
#   'QUEIMADOS AEREO',
#   'QUEIMADOS AEREO',
#   'COELHO DA ROCHA',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'COELHO DA ROCHA',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'ROCHA FREIRE AEREO AT/MT',
#   'CAXIAS AEREO',
#   'QUEIMADOS AEREO',
#   'QUEIMADOS AEREO',
#   'QUEIMADOS AEREO',
#   'COELHO DA ROCHA',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'COSMOS',
#   'CARMARI',
#   'CENTENARIO AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'CENTENARIO AEREO MT/MT',
#   'ELDORADO',
#   'AREIA BRANCA AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'AREIA BRANCA AEREO',
#   'SEROPEDICA AEREO',
#   'COELHO DA ROCHA',
#   'VILA VALQUEIRE',
#   'QUEIMADOS AEREO',
#   'CURICICA AEREO',
#   'PIEDADE',
#   'CENTENARIO AEREO AT/MT',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'AREIA BRANCA AEREO',
#   'COMENDADOR SOARES',
#   'SANTA CECILIA AEREO MT/MT',
#   'COELHO DA ROCHA',
#   'ITAPEBA AEREO URBANO',
#   'SAUDADE',
#   'VIGARIO',
#   'INMETRO',
#   'AREIA BRANCA AEREO',
#   'AREIA BRANCA AEREO',
#   'LEOPOLDO AEREO',
#   'QUEIMADOS AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'TROVAO AEREO',
#   'ELDORADO',
#   'CENTENARIO AEREO MT/MT',
#   'ROCHA FREIRE AEREO MT/MT',
#   'ROCHA FREIRE AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'CASCADURA AEREO',
#   'CASCADURA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'COLEGIO AEREO',
#   'VIGARIO',
#   'COSMOS',
#   'TURIACU',
#   'VILA VALQUEIRE',
#   'CENTENARIO AEREO AT/MT',
#   'URUGUAI AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'SANTA CECILIA AEREO MT/MT',
#   'BRISA MAR',
#   'PEDRO ERNESTO AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'NOVA IGUACU',
#   'FREI CANECA AEREO',
#   'HUMAITA AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'SANTO ANTONIO AEREO URBANO',
#   'CENTENARIO AEREO AT/MT',
#   'PORTA DAGUA AEREO',
#   'BRISA MAR',
#   'BRISA MAR',
#   'CURICICA AEREO',
#   'AREIA BRANCA AEREO',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SANTO ANTONIO AEREO URBANO',
#   'TURIACU',
#   'FREI CANECA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CAMARA',
#   'MERITI',
#   'SEROPEDICA AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CENTENARIO AEREO AT/MT',
#   'SAPUCAIA',
#   'SANTA CECILIA AEREO MT/MT',
#   'BRISA MAR',
#   'BRISA MAR',
#   'BARRA AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'MATURACA AEREO',
#   'CACHAMORRA',
#   'HUMAITA AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'VILAR DOS TELES AEREO',
#   'ZONA INDUSTRIAL',
#   'CENTENARIO AEREO AT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'TERRA NOVA AEREO',
#   'MARAPICU',
#   'CACHAMORRA',
#   'TROVAO AEREO',
#   'BRAS DE PINA',
#   'SANTA CECILIA AEREO MT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'BOCA DO MATO AEREO',
#   'SEROPEDICA AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'PEDRO ERNESTO AEREO',
#   'SEROPEDICA AEREO',
#   'ROSALI',
#   'VILAR DOS TELES AEREO',
#   'TAQUARA AEREO',
#   'TAQUARA AEREO',
#   'SANTO ANTONIO AEREO URBANO',
#   'SANTO ANTONIO AEREO URBANO',
#   'VIGARIO',
#   'JABOATAO AEREO',
#   'HUMAITA AEREO',
#   'JABOATAO AEREO',
#   'CENTENARIO AEREO AT/MT',
#   'CURICICA AEREO',
#   'POSTO SEIS AEREO URBANO',
#   'CURICICA AEREO',
#   'PEDRO ERNESTO AEREO',
#   'BAEPENDI AEREO',
#   'TERRA NOVA AEREO',
#   'TERRA NOVA AEREO',
#   'HUMAITA AEREO',
#   'PEDRO ERNESTO AEREO',
#   'GOVERNADOR AEREO',
#   'COSMOS',
#   'CACHAMORRA',
#   'CACHAMORRA',
#   'CACHAMORRA',
#   'VIGARIO GERAL AEREO',
#   'JABOATAO AEREO',
#   'SAPUCAIA',
#   'CURICICA AEREO',
#   'WASHINGTON LUIS AEREO',
#   'CAMARA',
#   'BRISA MAR',
#   'ESPERANCA AEREO MT/MT',
#   'SEROPEDICA AEREO',
#   'JABOATAO AEREO',
#   'BOCA DO MATO AEREO',
#   'CASCADURA AEREO',
#   'PEDRO ERNESTO AEREO',
#   'MENA BARRETO AEREO',
#   'CURICICA AEREO',
#   'CENTENARIO AEREO MT/MT',
#   'INMETRO',
#   'VIGARIO',
#   'PEDRO ERNESTO AEREO',
#   'AREIA BRANCA AEREO',
#   'AGUA GRANDE AEREO',
#   'COMENDADOR SOARES',
#   'SEROPEDICA AEREO',
#   'CURICICA AEREO',
#   'CASCADURA AEREO',
#   'TERRA NOVA AEREO',
#   'TERRA NOVA AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'PEDRO ERNESTO AEREO',
#   'CURICICA AEREO',
#   'VOLTA REDONDA AEREO AT/MT',
#   'BARRA 2',
#   'ITAGUAI',
#   'FONTINELE',
#   'RETIRO',
#   'CASCADURA AEREO',
#   'NOVA IGUACU',
#   'WASHINGTON LUIS AEREO',
#   'MENA BARRETO AEREO',
#   'HUMAITA AEREO',
#   'POSTO SEIS SUBTERRANEO',
#   'JABOATAO AEREO',
#   'ELDORADO',
#   'CENTENARIO AEREO AT/MT',
#   'TRES RIOS AEREO MT/MT',
#   'CARMARI',
#   'PEDRO ERNESTO AEREO',
#   'TAQUARA AEREO',
#   'COELHO DA ROCHA',
#   'ARI FRANCO',
#   'CACHAMORRA',
#   'CENTENARIO AEREO MT/MT',
#   'TERRA NOVA AEREO',
#   'SEROPEDICA AEREO',
#   'MENA BARRETO AEREO',
#   'BRISA MAR',
#   'BRISA MAR',
#   'GUADALUPE AEREO',
#   'CACHAMORRA',
#   'CENTENARIO AEREO AT/MT',
#   'VOLTA REDONDA AEREO AT/MT',
#   'BRISA MAR',
#   'PORTA DAGUA AEREO',
#   'ESPERANCA AEREO AT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'ESPERANCA AEREO AT/MT',
#   'PEDRO ERNESTO AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'ROSALI',
#   'PAVUNA',
#   'PIEDADE',
#   'SAPUCAIA',
#   'VOLTA REDONDA AEREO MT/MT',
#   'TURIACU',
#   'ITAPEBA AEREO URBANO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'TRIAGEM AEREO',
#   'BRISA MAR',
#   'RETIRO',
#   'VIGARIO GERAL AEREO',
#   'SANTA CECILIA AEREO MT/MT',
#   'ROSALI',
#   'INMETRO',
#   'INMETRO',
#   'MATURACA AEREO',
#   'PIEDADE',
#   'SEROPEDICA AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'BRAS DE PINA',
#   'CAMARA',
#   'CENTENARIO AEREO MT/MT',
#   'AREIA BRANCA AEREO',
#   'AREIA BRANCA AEREO',
#   'AREIA BRANCA AEREO',
#   'AREIA BRANCA AEREO',
#   'COMENDADOR SOARES',
#   'CASCADURA AEREO',
#   'QUEIMADOS AEREO',
#   'PORTA DAGUA AEREO',
#   'GUADALUPE AEREO',
#   'BRISA MAR',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'ITAGUAI',
#   'RETIRO',
#   'CASCADURA AEREO',
#   'PAVUNA',
#   'TURIACU',
#   'PIEDADE',
#   'JABOATAO AEREO',
#   'ROSALI',
#   'PIEDADE',
#   'PADRE MIGUEL',
#   'RETIRO',
#   'URUGUAI AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'CURICICA AEREO',
#   'PADRE MIGUEL',
#   'GUANABARA AEREO',
#   'CASCADURA AEREO',
#   'BRISA MAR',
#   'ESPERANCA AEREO AT/MT',
#   'COELHO DA ROCHA',
#   'ARI FRANCO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'PORTA DAGUA AEREO',
#   'TRES RIOS AEREO AT/MT',
#   'TRES RIOS AEREO AT/MT',
#   'LEME AEREO URBANO',
#   'BRAS DE PINA',
#   'CARMARI',
#   'TROVAO AEREO',
#   'VIGARIO',
#   'VIGARIO',
#   'VIGARIO',
#   'MERITI',
#   'CASCADURA AEREO',
#   'VOLTA REDONDA AEREO MT/MT',
#   'AREIA BRANCA AEREO',
#   'PAVUNA',
#   'SANTA CECILIA AEREO AT/MT',
#   'ESPERANCA AEREO MT/MT',
#   'SEROPEDICA AEREO',
#   'SEROPEDICA AEREO',
#   'SARAPUI',
#   'AGUA GRANDE AEREO',
#   'MATO ALTO',
#   'TAQUARA AEREO',
#   'CARMARI',
#   'ITAPEBA AEREO URBANO',
#   'CURICICA AEREO',
#   'VIGARIO GERAL AEREO',
#   'TRES RIOS AEREO MT/MT',
#   'CURICICA AEREO',
#   'TAQUARA AEREO',
#   ...]}

# %%
with open("/content/drive/MyDrive/Mestrado/Ordens_servico/Ordens_servico/CONJUNTOS_LIGHT.json", 'w') as f:
  json.dump(interrupcoes_dict, f)
